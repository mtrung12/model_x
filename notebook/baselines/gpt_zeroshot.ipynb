# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../..'))
import pandas as pd

# %%
import time
from src.baselines.evaluate import run_parallel

# %%
test_csv = '../../data/split/essays/test.csv'
test_df = pd.read_csv(test_csv)
small_test_csv = '../../data/split/essays/minor_test.csv'
small_test_df = pd.read_csv(small_test_csv)
test_df.head(5)
# Out:
#                                                 text  cEXT  cNEU  cAGR  cCON  \
# 0  Well I'm sitting here wondering why I have to ...  high   low  high  high
# 1  I have a paper to start writing for English, a...  high  high   low   low
# 2  I know that I have assignments to take care of...   low  high  high   low
# 3  Well im listening to Dave matthews , what do y...  high  high   low   low
# 4  College presents a life that is quite differen...  high  high  high  high
#
#    cOPN  label
# 0  high  11101
# 1   low     11
# 2   low    110
# 3  high  10011
# 4   low   1111

# %%
model = 'gpt-4o-mini'
prompt_mode = 'zeroshot'
output_dir = f'../../experiment/{model}/{prompt_mode}'
max_concurrency = 10
max_new_tokens = 512

# %%
result_df, result_path = run_parallel(small_test_csv, model, max_new_tokens, prompt_mode, output_dir=output_dir, max_concurrency=max_concurrency)
print(f'The result has been successfully saved to {result_path}')
# Out:
# [20260325-143638] Loaded 2 records from ../../data/split/essays/minor_test.csv
# Running with prompt_mode=zeroshot, max_concurrency=10
# Done in 5.2s (2.59s/record). 0 record(s) had errors.
# Raw predictions saved to ../../experiment/gpt-4o-mini/zeroshot\raw_predictions.csv
# Classification report saved to ../../experiment/gpt-4o-mini/zeroshot\classification_report.txt
# The result has been successfully saved to ../../experiment/gpt-4o-mini/zeroshot\classification_report.txt
